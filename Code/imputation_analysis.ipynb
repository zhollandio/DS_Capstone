# %% [markdown]
# ## Setup and define emission variables

# %%
from google.cloud import bigquery
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

client = bigquery.Client(project='code-for-planet')

# Define emission-related variables to analyze
emission_vars = [
    'area_burned', 'prefire_fuel', 'consumed_fuel',
    'ECO2', 'ECO', 'ECH4', 'EPM2_5', 'cwd_frac', 'duff_frac'
]

# %% [markdown]
# ## Basic counts - total records and null/zero patterns

# %%
basic_counts_query = """
SELECT
    COUNT(*) as total_records,
    COUNT(DISTINCT year) as years_covered,
    COUNT(DISTINCT global_fire_event_id) as unique_fire_events,
    MIN(year) as min_year,
    MAX(year) as max_year
FROM `code-for-planet.emission_db.emissions_db_final`
"""

basic_counts = client.query(basic_counts_query).to_dataframe()
basic_counts
# Out:
#    total_records  years_covered  unique_fire_events  min_year  max_year
# 0        7254534             13             1028764      2003      2015

# %% [markdown]
# ## Null value analysis for each emission variable

# %%
null_analysis_query = f"""
SELECT
    {', '.join([f'COUNTIF({var} IS NULL) as {var}_nulls' for var in emission_vars])},
    {', '.join([f'COUNTIF({var} IS NULL) * 100.0 / COUNT(*) as {var}_null_pct' for var in emission_vars])},
    COUNT(*) as total_records
FROM `code-for-planet.emission_db.emissions_db_final`
"""

null_analysis = client.query(null_analysis_query).to_dataframe()
null_analysis
# Out:
#    area_burned_nulls  prefire_fuel_nulls  consumed_fuel_nulls  ECO2_nulls  \
# 0                  0                   0                    0           0
#
#    ECO_nulls  ECH4_nulls  EPM2_5_nulls  cwd_frac_nulls  duff_frac_nulls  \
# 0          0           0             0               0                0
#
#    area_burned_null_pct  prefire_fuel_null_pct  consumed_fuel_null_pct  \
# 0                   0.0                    0.0                     0.0
#
#    ECO2_null_pct  ECO_null_pct  ECH4_null_pct  EPM2_5_null_pct  \
# 0            0.0           0.0            0.0              0.0
#
#    cwd_frac_null_pct  duff_frac_null_pct  total_records
# 0                0.0                 0.0        7254534

# %% [markdown]
# ## Zero value analysis for each emission variable

# %%
zero_analysis_query = f"""
SELECT
    {', '.join([f'COUNTIF({var} = 0) as {var}_zeros' for var in emission_vars])},
    {', '.join([f'COUNTIF({var} = 0) * 100.0 / COUNT(*) as {var}_zero_pct' for var in emission_vars])},
    COUNT(*) as total_records
FROM `code-for-planet.emission_db.emissions_db_final`
"""

zero_analysis = client.query(zero_analysis_query).to_dataframe()
zero_analysis
# Out:
#    area_burned_zeros  prefire_fuel_zeros  consumed_fuel_zeros  ECO2_zeros  \
# 0            2312632             1293962              1293962     1293962
#
#    ECO_zeros  ECH4_zeros  EPM2_5_zeros  cwd_frac_zeros  duff_frac_zeros  \
# 0    1293962     1293962       1293962         4472065          4472065
#
#    area_burned_zero_pct  prefire_fuel_zero_pct  consumed_fuel_zero_pct  \
# 0             31.878436              17.836597               17.836597
#
#    ECO2_zero_pct  ECO_zero_pct  ECH4_zero_pct  EPM2_5_zero_pct  \
# 0      17.836597     17.836597      17.836597        17.836597
#
#    cwd_frac_zero_pct  duff_frac_zero_pct  total_records
# 0          61.645104           61.645104        7254534

# %% [markdown]
# ## Combined null and zero analysis

# %%
combined_analysis_query = f"""
SELECT
    {', '.join([f'COUNTIF({var} IS NULL OR {var} = 0) as {var}_null_or_zero' for var in emission_vars])},
    {', '.join([f'COUNTIF({var} IS NULL OR {var} = 0) * 100.0 / COUNT(*) as {var}_null_or_zero_pct' for var in emission_vars])},
    {', '.join([f'COUNTIF({var} > 0) as {var}_positive_values' for var in emission_vars])},
    COUNT(*) as total_records
FROM `code-for-planet.emission_db.emissions_db_final`
"""

combined_analysis = client.query(combined_analysis_query).to_dataframe()
combined_analysis
# Out:
#    area_burned_null_or_zero  prefire_fuel_null_or_zero  \
# 0                   2312632                    1293962
#
#    consumed_fuel_null_or_zero  ECO2_null_or_zero  ECO_null_or_zero  \
# 0                     1293962            1293962           1293962
#
#    ECH4_null_or_zero  EPM2_5_null_or_zero  cwd_frac_null_or_zero  \
# 0            1293962              1293962                4472065
#
#    duff_frac_null_or_zero  area_burned_null_or_zero_pct  ...  \
# 0                 4472065                     31.878436  ...
#
#    area_burned_positive_values  prefire_fuel_positive_values  \
# 0                      4941902                       5960572
#
#    consumed_fuel_positive_values  ECO2_positive_values  ECO_positive_values  \
# 0                        5960572               5960572              5960572
#
#    ECH4_positive_values  EPM2_5_positive_values  cwd_frac_positive_values  \
# 0               5960572                 5960572                   2782469
#
#    duff_frac_positive_values  total_records
# 0                    2782469        7254534
#
# [1 rows x 28 columns]

# %% [markdown]
# ## Year-by-year patterns

# %%
yearly_patterns_query = f"""
SELECT
    year,
    COUNT(*) as records_per_year,
    {', '.join([f'COUNTIF({var} = 0) as {var}_zeros' for var in emission_vars])},
    {', '.join([f'COUNTIF({var} IS NULL) as {var}_nulls' for var in emission_vars])},
    {', '.join([f'COUNTIF({var} > 0) as {var}_positive' for var in emission_vars])}
FROM `code-for-planet.emission_db.emissions_db_final`
GROUP BY year
ORDER BY year
"""

yearly_patterns = client.query(yearly_patterns_query).to_dataframe()
yearly_patterns
# Out:
#     year  records_per_year  area_burned_zeros  prefire_fuel_zeros  \
# 0   2003            424715             167097              107362
# 1   2004            239663             111449               75029
# 2   2005            473253             156518               73425
# 3   2006            813256             246124               97249
# 4   2007            754083             253939              114044
# 5   2008            523941             168336               83053
# 6   2009            484933             155750              109092
# 7   2010            378858             153504              108372
# 8   2011            883243             204759              112988
# 9   2012            731744             166475               64715
# 10  2013            317975              90338               45569
# 11  2014            558889             177899              116786
# 12  2015            669981             260444              186278
#
#     consumed_fuel_zeros  ECO2_zeros  ECO_zeros  ECH4_zeros  EPM2_5_zeros  \
# 0                107362      107362     107362      107362        107362
# 1                 75029       75029      75029       75029         75029
# 2                 73425       73425      73425       73425         73425
# 3                 97249       97249      97249       97249         97249
# 4                114044      114044     114044      114044        114044
# 5                 83053       83053      83053       83053         83053
# 6                109092      109092     109092      109092        109092
# 7                108372      108372     108372      108372        108372
# 8                112988      112988     112988      112988        112988
# 9                 64715       64715      64715       64715         64715
# 10                45569       45569      45569       45569         45569
# 11               116786      116786     116786      116786        116786
# 12               186278      186278     186278      186278        186278
#
#     cwd_frac_zeros  ...  duff_frac_nulls  area_burned_positive  \
# 0           247882  ...                0                257618
# 1           132065  ...                0                128214
# 2           313665  ...                0                316735
# 3           581290  ...                0                567132
# 4           436808  ...                0                500144
# 5           318252  ...                0                355605
# 6           310850  ...                0                329183
# 7           226446  ...                0                225354
# 8           584428  ...                0                678484
# 9           431923  ...                0                565269
# 10          136746  ...                0                227637
# 11          348086  ...                0                380990
# 12          403624  ...                0                409537
#
#     prefire_fuel_positive  consumed_fuel_positive  ECO2_positive  \
# 0                  317353                  317353         317353
# 1                  164634                  164634         164634
# 2                  399828                  399828         399828
# 3                  716007                  716007         716007
# 4                  640039                  640039         640039
# 5                  440888                  440888         440888
# 6                  375841                  375841         375841
# 7                  270486                  270486         270486
# 8                  770255                  770255         770255
# 9                  667029                  667029         667029
# 10                 272406                  272406         272406
# 11                 442103                  442103         442103
# 12                 483703                  483703         483703
#
#     ECO_positive  ECH4_positive  EPM2_5_positive  cwd_frac_positive  \
# 0         317353         317353           317353             176833
# 1         164634         164634           164634             107598
# 2         399828         399828           399828             159588
# 3         716007         716007           716007             231966
# 4         640039         640039           640039             317275
# 5         440888         440888           440888             205689
# 6         375841         375841           375841             174083
# 7         270486         270486           270486             152412
# 8         770255         770255           770255             298815
# 9         667029         667029           667029             299821
# 10        272406         272406           272406             181229
# 11        442103         442103           442103             210803
# 12        483703         483703           483703             266357
#
#     duff_frac_positive
# 0               176833
# 1               107598
# 2               159588
# 3               231966
# 4               317275
# 5               205689
# 6               174083
# 7               152412
# 8               298815
# 9               299821
# 10              181229
# 11              210803
# 12              266357
#
# [13 rows x 29 columns]

# %% [markdown]
# ## Statistical summary for positive values only

# %%
positive_stats_query = f"""
SELECT
    {', '.join([f'MIN(CASE WHEN {var} > 0 THEN {var} END) as {var}_min_positive' for var in emission_vars])},
    {', '.join([f'MAX({var}) as {var}_max' for var in emission_vars])},
    {', '.join([f'AVG(CASE WHEN {var} > 0 THEN {var} END) as {var}_mean_positive' for var in emission_vars])},
    {', '.join([f'APPROX_QUANTILES({var}, 100)[OFFSET(50)] as {var}_median_all' for var in emission_vars])},
    {', '.join([f'APPROX_QUANTILES(CASE WHEN {var} > 0 THEN {var} END, 100)[OFFSET(50)] as {var}_median_positive' for var in emission_vars])}
FROM `code-for-planet.emission_db.emissions_db_final`
"""

positive_stats = client.query(positive_stats_query).to_dataframe()
positive_stats
# Out:
#    area_burned_min_positive  prefire_fuel_min_positive  \
# 0                   62500.0                   3.810924
#
#    consumed_fuel_min_positive  ECO2_min_positive  ECO_min_positive  \
# 0                    3.544159           5.943555          0.248091
#
#    ECH4_min_positive  EPM2_5_min_positive  cwd_frac_min_positive  \
# 0           0.009498              0.03615               0.002261
#
#    duff_frac_min_positive  area_burned_max  ...  duff_frac_median_all  \
# 0                0.026048          62500.0  ...                   0.0
#
#    area_burned_median_positive  prefire_fuel_median_positive  \
# 0                      62500.0                   1470.119976
#
#    consumed_fuel_median_positive  ECO2_median_positive  ECO_median_positive  \
# 0                    1251.245086            1989.28649            92.652866
#
#    ECH4_median_positive  EPM2_5_median_positive  cwd_frac_median_positive  \
# 0              3.547281               13.500846                   0.10764
#
#    duff_frac_median_positive
# 0                   0.173202
#
# [1 rows x 45 columns]

# %% [markdown]
# ## Cross-variable zero patterns (which variables are zero together)

# %%
cross_zero_patterns_query = """
SELECT
    CASE WHEN area_burned = 0 THEN 'zero' ELSE 'positive' END as area_burned_status,
    CASE WHEN ECO2 = 0 THEN 'zero' ELSE 'positive' END as ECO2_status,
    CASE WHEN ECO = 0 THEN 'zero' ELSE 'positive' END as ECO_status,
    CASE WHEN ECH4 = 0 THEN 'zero' ELSE 'positive' END as ECH4_status,
    CASE WHEN consumed_fuel = 0 THEN 'zero' ELSE 'positive' END as consumed_fuel_status,
    COUNT(*) as record_count,
    COUNT(*) * 100.0 / SUM(COUNT(*)) OVER() as percentage
FROM `code-for-planet.emission_db.emissions_db_final`
GROUP BY 1,2,3,4,5
ORDER BY record_count DESC
"""

cross_zero_patterns = client.query(cross_zero_patterns_query).to_dataframe()
cross_zero_patterns
# Out:
#   area_burned_status ECO2_status ECO_status ECH4_status consumed_fuel_status  \
# 0           positive    positive   positive    positive             positive
# 1               zero    positive   positive    positive             positive
# 2               zero        zero       zero        zero                 zero
# 3           positive        zero       zero        zero                 zero
#
#    record_count  percentage
# 0       4761421   65.633726
# 1       1199151   16.529676
# 2       1113481   15.348760
# 3        180481    2.487837

# %% [markdown]
# ## Regional patterns (by covertype and fuelcode)

# %%
regional_patterns_query = """
SELECT
    covertype,
    fuelcode,
    COUNT(*) as total_records,
    COUNTIF(ECO2 = 0) as ECO2_zeros,
    COUNTIF(area_burned = 0) as area_burned_zeros,
    COUNTIF(ECO2 = 0) * 100.0 / COUNT(*) as ECO2_zero_pct,
    COUNTIF(area_burned = 0) * 100.0 / COUNT(*) as area_burned_zero_pct,
    AVG(CASE WHEN ECO2 > 0 THEN ECO2 END) as avg_ECO2_when_positive,
    AVG(CASE WHEN area_burned > 0 THEN area_burned END) as avg_area_burned_when_positive
FROM `code-for-planet.emission_db.emissions_db_final`
GROUP BY covertype, fuelcode
HAVING COUNT(*) >= 100
ORDER BY ECO2_zero_pct DESC
"""


regional_patterns = client.query(regional_patterns_query).to_dataframe()
regional_patterns
# Out:
#     covertype  fuelcode  total_records  ECO2_zeros  area_burned_zeros  \
# 0           0         0         134288      134288              85127
# 1          95         0         145703      145703              71562
# 2          90         0          15677       15677              10503
# 3          22         0          10864       10864              10093
# 4          82         0         845208      845208             827580
# 5          21         0          25416       25416              21007
# 6          81         0         110375      110375              81475
# 7          23         0           5036        5036               4783
# 8          24         0           1369        1369               1347
# 9           2         2        1523239          26             250994
# 10          1         1        1654890           0             285486
# 11          3      1140         342021           0              91055
# 12          3      1400          68147           0              17623
# 13          3      1600         110018           0              30147
# 14          3      1160         276662           0              63763
# 15          3      1500         386969           0             101901
# 16          3      2700          28381           0               6856
# 17          3      1950          10502           0               2220
# 18          3      1920         122231           0              19775
# 19          3      1180         223461           0              54277
# 20          3      2180          12468           0               1816
# 21          3      1200         323936           0              73196
# 22          3      1260         197818           0              45230
# 23          3      1220         320896           0              80733
# 24          3      2950           4849           0                936
# 25          3      1100           6851           0               1035
# 26          3      1800           8188           0               2223
# 27          3      1370         165640           0              33038
# 28          3      1340           2315           0                810
# 29          3      1900          14508           0               3093
# 30          3      1360          14728           0               4050
# 31          3      1910            257           0                 70
# 32          3      1940           7317           0               2039
# 33          3      1280         105916           0              21419
# 34          3      1700            290           0                 90
# 35          3      2900          15624           0               3065
# 36          3      1120           5671           0               1079
# 37          3      1300           2704           0                572
# 38          3      1320           3306           0                390
# 39          3      1240            116           0                 58
# 40          3      1980            667           0                115
#
#     ECO2_zero_pct  area_burned_zero_pct  avg_ECO2_when_positive  \
# 0      100.000000             63.391368                     NaN
# 1      100.000000             49.114980                     NaN
# 2      100.000000             66.996237                     NaN
# 3      100.000000             92.903166                     NaN
# 4      100.000000             97.914360                     NaN
# 5      100.000000             82.652660                     NaN
# 6      100.000000             73.816535                     NaN
# 7      100.000000             94.976172                     NaN
# 8      100.000000             98.392988                     NaN
# 9        0.001707             16.477651             1064.753764
# 10       0.000000             17.251056              348.009536
# 11       0.000000             26.622634             6360.883040
# 12       0.000000             25.860273             5737.404666
# 13       0.000000             27.401880             3659.345043
# 14       0.000000             23.047256             6244.604399
# 15       0.000000             26.333117             3954.837359
# 16       0.000000             24.157006             3067.699339
# 17       0.000000             21.138831             3588.602990
# 18       0.000000             16.178384             5378.279708
# 19       0.000000             24.289250             2397.868244
# 20       0.000000             14.565287             1905.205028
# 21       0.000000             22.595821             6485.701190
# 22       0.000000             22.864451             7054.181955
# 23       0.000000             25.158618             4994.699630
# 24       0.000000             19.302949             1562.110555
# 25       0.000000             15.107284             9355.025179
# 26       0.000000             27.149487             8474.997579
# 27       0.000000             19.945665             8189.910729
# 28       0.000000             34.989201            12459.605845
# 29       0.000000             21.319272             7699.888741
# 30       0.000000             27.498642             2929.577378
# 31       0.000000             27.237354            10306.648506
# 32       0.000000             27.866612             9354.785386
# 33       0.000000             20.222629             7335.112961
# 34       0.000000             31.034483             6733.877355
# 35       0.000000             19.617256             8719.251101
# 36       0.000000             19.026627            12762.185706
# 37       0.000000             21.153846            11017.316700
# 38       0.000000             11.796733            10660.840356
# 39       0.000000             50.000000             4969.969705
# 40       0.000000             17.241379             3023.742661
#
#     avg_area_burned_when_positive
# 0                         62500.0
# 1                         62500.0
# 2                         62500.0
# 3                         62500.0
# 4                         62500.0
# 5                         62500.0
# 6                         62500.0
# 7                         62500.0
# 8                         62500.0
# 9                         62500.0
# 10                        62500.0
# 11                        62500.0
# 12                        62500.0
# 13                        62500.0
# 14                        62500.0
# 15                        62500.0
# 16                        62500.0
# 17                        62500.0
# 18                        62500.0
# 19                        62500.0
# 20                        62500.0
# 21                        62500.0
# 22                        62500.0
# 23                        62500.0
# 24                        62500.0
# 25                        62500.0
# 26                        62500.0
# 27                        62500.0
# 28                        62500.0
# 29                        62500.0
# 30                        62500.0
# 31                        62500.0
# 32                        62500.0
# 33                        62500.0
# 34                        62500.0
# 35                        62500.0
# 36                        62500.0
# 37                        62500.0
# 38                        62500.0
# 39                        62500.0
# 40                        62500.0

# %% [markdown]
# ## Fire event level analysis

# %%
fire_event_analysis_query = """
SELECT
    COUNTIF(all_zero_emissions) as events_with_all_zero_emissions,
    COUNTIF(mixed_emissions) as events_with_mixed_emissions,
    COUNTIF(all_positive_emissions) as events_with_all_positive_emissions,
    COUNT(*) as total_fire_events
FROM (
    SELECT
        global_fire_event_id,
        COUNTIF(ECO2 = 0 AND ECO = 0 AND ECH4 = 0) = COUNT(*) as all_zero_emissions,
        COUNTIF(ECO2 > 0 AND ECO > 0 AND ECH4 > 0) = COUNT(*) as all_positive_emissions,
        COUNTIF(ECO2 = 0 AND ECO = 0 AND ECH4 = 0) > 0
        AND COUNTIF(ECO2 > 0 OR ECO > 0 OR ECH4 > 0) > 0 as mixed_emissions
    FROM `code-for-planet.emission_db.emissions_db_final`
    WHERE global_fire_event_id IS NOT NULL
    GROUP BY global_fire_event_id
)
"""

fire_event_analysis = client.query(fire_event_analysis_query).to_dataframe()
fire_event_analysis
# Out:
#    events_with_all_zero_emissions  events_with_mixed_emissions  \
# 0                          255751                        70834
#
#    events_with_all_positive_emissions  total_fire_events
# 0                              702179            1028764

# %% [markdown]
# ## Temporal patterns within fire events

# %%
temporal_patterns_query = """
SELECT
    days_from_event_start,
    COUNT(*) as total_records,
    COUNTIF(ECO2 = 0) as ECO2_zeros,
    COUNTIF(area_burned = 0) as area_burned_zeros,
    COUNTIF(ECO2 = 0) * 100.0 / COUNT(*) as ECO2_zero_pct,
    AVG(CASE WHEN ECO2 > 0 THEN ECO2 END) as avg_ECO2_when_positive
FROM `code-for-planet.emission_db.emissions_db_final`
WHERE days_from_event_start IS NOT NULL
AND days_from_event_start BETWEEN 0 AND 30
GROUP BY days_from_event_start
ORDER BY days_from_event_start
"""

temporal_patterns = client.query(temporal_patterns_query).to_dataframe()
temporal_patterns
# Out:
#     days_from_event_start  total_records  ECO2_zeros  area_burned_zeros  \
# 0                       0        3592217      716706            1159770
# 1                       1        1000288      118936             261115
# 2                       2         643644      101787             197736
# 3                       3         426310       71218             134063
# 4                       4         329401       57008             102563
# 5                       5         237649       43217              81714
# 6                       6         169550       36296              61414
# 7                       7         140512       26934              51312
# 8                       8         108968       20935              40460
# 9                       9          86472       16912              32820
# 10                     10          58421       10604              22471
# 11                     11          51898        8133              17473
# 12                     12          41740        6995              15061
# 13                     13          39005        6218              13468
# 14                     14          34599        5766              12743
# 15                     15          29777        4477              10844
# 16                     16          28034        4563               9687
# 17                     17          26874        3658               8928
# 18                     18          22856        3298               7950
# 19                     19          20670        3130               7846
# 20                     20          18145        3095               6447
# 21                     21          14257        2264               5219
# 22                     22          14257        1788               4644
# 23                     23          11213        1972               4062
# 24                     24          11053        1707               4033
# 25                     25           8284        1221               3086
# 26                     26           7790        1272               3163
# 27                     27           7342        1182               2628
# 28                     28           6292         711               2372
# 29                     29           4827         985               2136
# 30                     30           5926         909               2359
#
#     ECO2_zero_pct  avg_ECO2_when_positive
# 0       19.951634             2502.141560
# 1       11.890176             2421.530388
# 2       15.814177             2876.068565
# 3       16.705684             3122.575203
# 4       17.306566             3244.972253
# 5       18.185223             3673.785250
# 6       21.407254             4131.068915
# 7       19.168470             4353.976923
# 8       19.212062             4392.651300
# 9       19.557776             4598.356631
# 10      18.151007             4951.064900
# 11      15.671124             5235.058344
# 12      16.758505             5369.166557
# 13      15.941546             5417.185182
# 14      16.665222             5493.936829
# 15      15.035094             5401.295054
# 16      16.276664             5450.344890
# 17      13.611669             5150.813361
# 18      14.429471             5191.550540
# 19      15.142719             5207.787582
# 20      17.057041             5152.379667
# 21      15.879919             5252.120277
# 22      12.541208             4940.584631
# 23      17.586730             5607.380011
# 24      15.443771             5494.747826
# 25      14.739256             5804.993454
# 26      16.328626             5674.296874
# 27      16.099156             5623.273117
# 28      11.300064             5973.369425
# 29      20.406049             5724.461003
# 30      15.339183             5946.199008
